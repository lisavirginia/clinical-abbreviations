# %% [markdown]
# # Step 4: Quality Check

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import re
from spellchecker import SpellChecker

# %%
# Suppress false positive warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Load Datasets

# %%
df = pd.read_csv('https://raw.githubusercontent.com/lisavirginia/clinical-abbreviations/master/modules/Step2Output_Clinical_Abbreviation_Acronym_Crosswalk.csv',
                 sep='|',
                 header=0,
                 index_col=False,
                 na_filter=False,
                 dtype=object)

# %%
df.sample(3, random_state=0)
# Out:
#        GroupID  EntryID      SF     SFUI  NormSF    NSFUI PrefSF  \
# 33582           E033583  α-GPDH  S103760  α_gpdh  N076113
# 70982           E070983   PRPPs  S056625   prpps  N057119
# 192802          E192803     IPH  S036667     iph  N036838
#
#                                              LF     LFUI  \
# 33582      alpha-glycerophosphate dehydrogenase  L041419
# 70982   phosphoribosyl pyrophosphate synthetase  L128319
# 192802             intra-peritoneal haemorrhage  L097757
#
#                                         NormLF PrefLF Source     SFEUI  \
# 33582     alpha glycerophosphate dehydrogenase          UMLS  E0412935
# 70982   phosphoribosylpyrophosphate synthetase          UMLS  E0571504
# 192802                                                  UMLS  E0703883
#
#            LFEUI     Type Score Count Frequency UMLS.CUI
# 33582   E0769306  acronym
# 70982   E0047486  acronym
# 192802  E0703882  acronym

# %%
df.shape
# Out:
# (413964, 19)

# %% [markdown]
# #### Instantiate Output

# %%
modify = []
retire = []

# %% [markdown]
# ## Identify Errors

# %% [markdown]
# #### Heuristic 1: Duplicates

# %% [markdown]
# Identify which entries exactly duplicate another entry from the same source.

# %%
Extract1 = df[df.duplicated(['SF', 'LF', 'Source' ]) == True]
df = df[df.duplicated(['SF', 'LF', 'Source' ]) == False]
Extract1['error'] = "duplicate"
Extract1.shape
# Out:
# (3942, 19)

# %%
retire.append(Extract1)

# %% [markdown]
# #### Heuristic 2: Punctuation

# %% [markdown]
# Identify excess punctuation in the long form (e.g. "nitric oxide;").

# %%
# Punctuation after LF (excludes .+%)
Extract2_1 = df[df['LF'].str.contains('.*[,\/#!\$\^&@\?<>\*:;{}=\-_\'~\(\)\[\]\"]$') == True]
df = df[df['LF'].str.contains('.*[,\/#!\$\^&@\?<>\*:;{}=\-_\'~\(\)\[\]\"]$') == False]
Extract2_1['error'] = "punctuation after LF"
Extract2_1.shape
# Out:
# (0, 20)

# %%
# Punctuation before LF (excludes .+%()[])
Extract2_2 = df[df['LF'].str.contains('^[,\/#!\$\^&@\?<>\*:;{}=\-_\'~\"].*') == True]
df = df[df['LF'].str.contains('^[,\/#!\$\^&@\?<>\*:;{}=\-_\'~\"].*') == False]
Extract2_2['error'] = "punctuation before LF"
Extract2_2.shape
# Out:
# (5, 19)

# %% [markdown]
# Identify excess punctuation in the short form (e.g. "..IVF").

# %%
# Excess periods before SF
Extract2_3 = df[df['SF'].str.contains('^[\.]+.*') == True] 
df = df[df['SF'].str.contains('^[\.]+.*') == False]
Extract2_3['error'] = "punctuation before SF"
Extract2_3.shape
# Out:
# (131, 19)

# %% [markdown]
# Append output

# %%
Extract2 = pd.concat([Extract2_1, Extract2_2, Extract2_3])
Extract2.shape
# Out:
# (2078, 19)

# %%
modify.append(Extract2)

# %% [markdown]
# #### Heuristic 3: Spelling

# %% [markdown]
# The long form contains spelling errors (e.g. "cncer").

# %%
# Set spell checker parameters
spell = SpellChecker(distance=1)

# Add medical word corpus (UMLS Metathesaurus)
spell.word_frequency.load_text_file('ClinSpell.txt')

# %%
# Exclude UMLS and ADAM
subset = df[df['Source'] != 'UMLS']
subset = subset[subset['Source'] != 'ADAM']

# Instantiate output
misspelled_rows = []
misspelled_data = []

# Iterate over subset
for index, row in subset.iterrows():
    
    # Format LF for spellchecker
    pre_token = re.sub('[^A-Za-z\s\-]+', '', row['LF']).lower()
    token = list(filter(None, re.split(r'[\s\-]+', pre_token)))
    
    # Identify misspelled LFs
    misspelled = spell.unknown(token)
    if len(misspelled) > 0:
        misspelled_rows.append(row['EntryID'])
        misspelled_data.append(misspelled)
        
# Extract misspelled LFs
Extract3 = df[df['EntryID'].isin(misspelled_rows)]
Extract3['error'] = misspelled_data
Extract3.shape
# Out:
# (409, 20)

# %%
modify.append(Extract3)

# %% [markdown]
# #### Heuristic 4: Content

# %% [markdown]
# The alphabetic characters in the short form don't occur anywhere in the long form.

# %%
# Exclude UMLS and ADAM
subset = df[df['Source'] != 'UMLS']
subset = subset[subset['Source'] != 'ADAM']

# Instantiate output
missing_characters = []

# Iterate over dataframe
for index, row in subset.iterrows():
    
    # Extract alphabetic characters
    alph_SF = set(re.sub('[^A-Za-z]+', '', row['SF']).lower())
    alph_LF = set(re.sub('[^A-Za-z]+', '', row['LF']).lower())
    
    if alph_SF.issubset(alph_LF) == False:
        missing_characters.append(row['EntryID'])
        
# Extract LFs missing characters
Extract3 = df[df['EntryID'].isin(missing_characters)]
Extract3.shape
# Out:
# (3993, 19)

# %%
Extract3.head(20)
# Out:
#        GroupID  EntryID    SF     SFUI NormSF    NSFUI PrefSF  \
# 401230          E401231    A0  S003024     a0  N002603
# 401231          E401232  disp  S085013   disp  N019983
# 401232          E401233  Disp  S020440   disp  N019983
# 401236          E401237  disp  S085013   disp  N019983
# 401240          E401241    A1  S003025     a1  N002604
# 401241          E401242  Disp  S020440   disp  N019983
# 401242          E401243  DISP  S019133   disp  N019983
# 401244          E401245   QOW  S058924    qow  N058304
# 401245          E401246   qow  S097392    qow  N058304
# 401246          E401247   A/P  S003018    a_p  N002776
# 401247          E401248   a/p  S077826    a_p  N002776
# 401248          E401249   QOW  S058924    qow  N058304
# 401249          E401250   qow  S097392    qow  N058304
# 401253          E401254   a/p  S077826    a_p  N002776
# 401254          E401255   A/P  S003018    a_p  N002776
# 401255          E401256    GU  S028714     gu  N029240
# 401259          E401260   A/P  S003018    a_p  N002776
# 401260          E401261    gu  S087520     gu  N029240
# 401264          E401265   A/P  S003018    a_p  N002776
# 401265          E401266    GT  S028624     gt  N029149
#
#                                             LF     LFUI              NormLF  \
# 401230                                dispense  L068584            dispense
# 401231                             0 abortions  L000101
# 401232                             0 abortions  L000101
# 401236                              1 abortion  L000103
# 401240                             disposition  L068603         disposition
# 401241  a1 segment of anterior cerebral artery  L037324
# 401242  a1 segment of anterior cerebral artery  L037324
# 401244                        every other week  L074786
# 401245                        every other week  L074786
# 401246                        every other week  L074786
# 401247                        every other week  L074786
# 401248                      anterior posterior  L043180  anterior posterior
# 401249                      anterior posterior  L043180  anterior posterior
# 401253                           genitourinary  L081386       genitourinary
# 401254                           genitourinary  L081386       genitourinary
# 401255                     assessment and plan  L046896
# 401259                                   guage  L083964
# 401260                          abdomen/pelvis  L037341
# 401264                        gastrostomy tube  L081036    gastrostomy tube
# 401265                          active/passive  L038520
#
#        PrefLF                     Source SFEUI LFEUI Type Score Count  \
# 401230           Vanderbilt Clinic Notes                            5
# 401231         Vanderbilt Discharge Sums                            9
# 401232         Vanderbilt Discharge Sums                            5
# 401236         Vanderbilt Discharge Sums                            2
# 401240           Vanderbilt Clinic Notes                            4
# 401241         Vanderbilt Discharge Sums                            7
# 401242         Vanderbilt Discharge Sums                            1
# 401244           Vanderbilt Clinic Notes                            4
# 401245           Vanderbilt Clinic Notes                            3
# 401246           Vanderbilt Clinic Notes                            2
# 401247           Vanderbilt Clinic Notes                            4
# 401248         Vanderbilt Discharge Sums                            4
# 401249         Vanderbilt Discharge Sums                            3
# 401253           Vanderbilt Clinic Notes                            2
# 401254           Vanderbilt Clinic Notes                            1
# 401255         Vanderbilt Discharge Sums                           21
# 401259           Vanderbilt Clinic Notes                            1
# 401260         Vanderbilt Discharge Sums                            1
# 401264           Vanderbilt Clinic Notes                            1
# 401265         Vanderbilt Discharge Sums                           23
#
#        Frequency  UMLS.CUI
# 401230     0.612  c1880359
# 401231       1.0  c0233107
# 401232       1.0  c0233107
# 401236    0.8675  c0233108
# 401240     0.369  c0743223
# 401241    0.1325  c0923398
# 401242    0.1325  c0923398
# 401244       1.0  c0585332
# 401245       1.0  c0585332
# 401246       1.0  c0585332
# 401247       1.0  c0585332
# 401248    0.9768  c1999039
# 401249    0.9768  c1999039
# 401253     0.996  c0042066
# 401254     0.996  c0042066
# 401255    0.0116  c1827496
# 401259     0.004  c0456564
# 401260    0.0039  c1508499
# 401264    0.9618  c0150595
# 401265    0.0039  c2721281

# %% [markdown]
# #### Export for Annotation

# %%
# Extract misspelled LFs
Extract3 = df[df['EntryID'].isin(misspelled_rows)]
Extract3['error'] = 
Extract3.shape

# %% [markdown]
# ## Modify or Retire

# %% [markdown]
# #### Import Annotated

# %%
df.head(5)
# Out:
#   GroupID  EntryID  SF     SFUI NormSF    NSFUI PrefSF                    LF  \
# 0          E000001  AA  S003081     aa  N002817              achievement age
# 1          E000002  AA  S003081     aa  N002817         Alcoholics Anonymous
# 2          E000003  AA  S003081     aa  N002817                alcohol abuse
# 3          E000004  AA  S003081     aa  N002817                alcohol-abuse
# 4          E000005  AA  S003081     aa  N002817              aortic aneurysm
#
#       LFUI           NormLF PrefLF Source     SFEUI     LFEUI     Type Score  \
# 0  L037913  achievement age          UMLS  E0000048  E0006859  acronym
# 1  L004250                           UMLS  E0000048  E0000204  acronym
# 2  L040702    alcohol abuse          UMLS  E0000048  E0356324  acronym
# 3  L040752    alcohol abuse          UMLS  E0000048  E0356324  acronym
# 4  L045559  aortic aneurysm          UMLS  E0000048  E0009858  acronym
#
#   Count Frequency UMLS.CUI
# 0
# 1
# 2
# 3
# 4
