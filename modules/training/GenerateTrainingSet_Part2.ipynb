# %% [markdown]
# # Generate Training Set (Part 2)

# %% [markdown]
# This training set compares long forms within each NSF.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import itertools
from fuzzywuzzy import fuzz

# %% [markdown]
# #### Load Dataset

# %%
df = pd.read_csv('https://raw.githubusercontent.com/lisavirginia/clinical-abbreviations/master/modules/Step2Output_Clinical_Abbreviation_Acronym_Crosswalk.csv',
                 sep='|',
                 header=0,
                 index_col=False,
                 na_filter=False,
                 dtype=object)

# %%
df.sample(3, random_state=0)
# Out:
#        GroupID  EntryID      SF     SFUI  NormSF    NSFUI PrefSF  \
# 33582           E033583  α-GPDH  S103760  α_gpdh  N076113
# 70982           E070983   PRPPs  S056625   prpps  N057119
# 192802          E192803     IPH  S036667     iph  N036838
#
#                                              LF     LFUI  \
# 33582      alpha-glycerophosphate dehydrogenase  L041419
# 70982   phosphoribosyl pyrophosphate synthetase  L128319
# 192802             intra-peritoneal haemorrhage  L097757
#
#                                         NormLF PrefLF Source     SFEUI  \
# 33582     alpha glycerophosphate dehydrogenase          UMLS  E0412935
# 70982   phosphoribosylpyrophosphate synthetase          UMLS  E0571504
# 192802                                                  UMLS  E0703883
#
#            LFEUI     Type Score Count Frequency UMLS.CUI
# 33582   E0769306  acronym
# 70982   E0047486  acronym
# 192802  E0703882  acronym

# %% [markdown]
# ## Initial Filtering

# %% [markdown]
# Identifies **most similar string** that is **not equivalent** within each **NSF**.
#
# We used the standard Levenshtein distance similarity ratio available [here](https://github.com/seatgeek/fuzzywuzzy).

# %% [markdown]
# #### Use Normalized Long Form Where Possible

# %%
df['TrainLF'] = np.where(df['NormLF']=='', df['LF'], df['NormLF'])

# %%
df.sample(3, random_state=0)
# Out:
#        GroupID  EntryID      SF     SFUI  NormSF    NSFUI PrefSF  \
# 33582           E033583  α-GPDH  S103760  α_gpdh  N076113
# 70982           E070983   PRPPs  S056625   prpps  N057119
# 192802          E192803     IPH  S036667     iph  N036838
#
#                                              LF     LFUI  \
# 33582      alpha-glycerophosphate dehydrogenase  L041419
# 70982   phosphoribosyl pyrophosphate synthetase  L128319
# 192802             intra-peritoneal haemorrhage  L097757
#
#                                         NormLF PrefLF Source     SFEUI  \
# 33582     alpha glycerophosphate dehydrogenase          UMLS  E0412935
# 70982   phosphoribosylpyrophosphate synthetase          UMLS  E0571504
# 192802                                                  UMLS  E0703883
#
#            LFEUI     Type Score Count Frequency UMLS.CUI  \
# 33582   E0769306  acronym
# 70982   E0047486  acronym
# 192802  E0703882  acronym
#
#                                        TrainLF
# 33582     alpha glycerophosphate dehydrogenase
# 70982   phosphoribosylpyrophosphate synthetase
# 192802            intra-peritoneal haemorrhage

# %%
df.shape
# Out:
# (413964, 20)

# %% [markdown]
# #### Compute Similarities

# %%
df = df.sort_values(by=['NSFUI'])
df.head(5)
# Out:
#        GroupID  EntryID              SF     SFUI          NormSF    NSFUI  \
# 287791          E287792  10 m walk test  S000333  10 m walk test  N000001
# 287790          E287791  10 m walk test  S000333  10 m walk test  N000001
# 287789          E287790  10 m walk test  S000333  10 m walk test  N000001
# 287788          E287789  10 m walk test  S000333  10 m walk test  N000001
# 287787          E287788  10 m walk test  S000333  10 m walk test  N000001
#
#        PrefSF                   LF     LFUI              NormLF PrefLF Source  \
# 287791         ten metre walk test  L155188  10 Meter Walk Test          UMLS
# 287790         ten meter walk test  L155187  10 Meter Walk Test          UMLS
# 287789         Ten Metre Walk Test  L033652  10 Meter Walk Test          UMLS
# 287788         Ten Meter Walk Test  L033651  10 Meter Walk Test          UMLS
# 287787          10 metre walk test  L000549  10 Meter Walk Test          UMLS
#
#            SFEUI     LFEUI          Type Score Count Frequency UMLS.CUI  \
# 287791  E0765285  E0765283  abbreviation
# 287790  E0765285  E0765283  abbreviation
# 287789  E0765285  E0765283  abbreviation
# 287788  E0765285  E0765283  abbreviation
# 287787  E0765285  E0765283  abbreviation
#
#                    TrainLF
# 287791  10 Meter Walk Test
# 287790  10 Meter Walk Test
# 287789  10 Meter Walk Test
# 287788  10 Meter Walk Test
# 287787  10 Meter Walk Test

# %%
train = []

# %%
for NSFUI in df.NSFUI.unique():
    uniq_LFs = set(df.loc[df['NSFUI'] == NSFUI]['TrainLF'].values)
    for pair in itertools.combinations(uniq_LFs, 2):
        distance = fuzz.ratio(pair[0], pair[1])
        if distance > 80:
            pair_dictionary = {'LF1':pair[0], 'LF2':pair[1], 'distance':distance} 
            train.append(pair_dictionary)

# %%
train = pd.DataFrame(train)

# %%
train.sample(3, random_state=0)
# Out:
#                             LF1                      LF2  distance
# 350681  protein kinase C betaII    protein kinase C β-II        86
# 134297       β-2 glycoprotein I       β(2)glycoprotein-I        83
# 306207  mast-cell-degranulating  mast cell-degranulating        96

# %% [markdown]
# ## Random Subset

# %% [markdown]
# Select random subset of highly and moderately similar long forms for manual annotation.

# %%
TrainSet3 = train[train.distance < 99]
TrainSet3 = TrainSet3.sample(frac=0.10)
TrainSet3 = TrainSet3.drop(columns=['distance'])
TrainSet3['Synonym'] = ''

# %%
TrainSet3.sample(3, random_state=0)
# Out:
#                                                       LF1  \
# 212464                              glucagon-like peptide
# 297868  light-harvesting chlorophyll a/b binding prote...
# 360159      peroxisome proliferator-activated receptor-γ2
#
#                                                       LF2 Synonym
# 212464                              glucagon like peptide
# 297868            light harvesting chlorophyll protein II
# 360159  peroxisome proliferator-activated receptor gam...

# %% [markdown]
# #### Export

# %%
TrainSet3.to_csv('TrainingSet3.csv',
                 index=False,
                 header=True,
                 sep='|')
