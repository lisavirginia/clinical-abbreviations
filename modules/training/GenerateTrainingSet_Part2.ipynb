# %% [markdown]
# # Generate Training Set (Part 2)

# %% [markdown]
# These training sets compare long forms within each NSF.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import itertools
from fuzzywuzzy import fuzz

# %% [markdown]
# #### Load Dataset

# %%
df = pd.read_csv('https://raw.githubusercontent.com/lisavirginia/clinical-abbreviations/master/modules/Step2Output_Clinical_Abbreviation_Acronym_Crosswalk.csv',
                 sep='|',
                 header=0,
                 index_col=False,
                 na_filter=False,
                 dtype=object)

# %%
df.sample(3, random_state=0)
# Out:
#        GroupID  EntryID      SF     SFUI  NormSF    NSFUI PrefSF  \
# 33582           E033583  α-GPDH  S103760  α_gpdh  N072157
# 70982           E070983   PRPPs  S056625   prpps  N248835
# 192802          E192803     IPH  S036667     iph  N193753
#
#                                              LF     LFUI  \
# 33582      alpha-glycerophosphate dehydrogenase  L041419
# 70982   phosphoribosyl pyrophosphate synthetase  L128319
# 192802             intra-peritoneal haemorrhage  L097757
#
#                                         NormLF PrefLF Source     SFEUI  \
# 33582     alpha glycerophosphate dehydrogenase          UMLS  E0412935
# 70982   phosphoribosylpyrophosphate synthetase          UMLS  E0571504
# 192802                                                  UMLS  E0703883
#
#            LFEUI     Type Score Count Frequency UMLS.CUI
# 33582   E0769306  acronym
# 70982   E0047486  acronym
# 192802  E0703882  acronym

# %% [markdown]
# ## Initial Filtering

# %% [markdown]
# Identifies **most similar string** that is **not equivalent** within each **NSF**.
#
# We used the standard Levenshtein distance similarity ratio available [here](https://github.com/seatgeek/fuzzywuzzy).

# %% [markdown]
# #### Use Normalized Long Form Where Possible

# %%
df['TrainLF'] = np.where(df['NormLF']=='', df['LF'], df['NormLF'])

# %%
df.sample(3, random_state=0)
# Out:
#        GroupID  EntryID      SF     SFUI  NormSF    NSFUI PrefSF  \
# 33582           E033583  α-GPDH  S103760  α_gpdh  N072157
# 70982           E070983   PRPPs  S056625   prpps  N248835
# 192802          E192803     IPH  S036667     iph  N193753
#
#                                              LF     LFUI  \
# 33582      alpha-glycerophosphate dehydrogenase  L041419
# 70982   phosphoribosyl pyrophosphate synthetase  L128319
# 192802             intra-peritoneal haemorrhage  L097757
#
#                                         NormLF PrefLF Source     SFEUI  \
# 33582     alpha glycerophosphate dehydrogenase          UMLS  E0412935
# 70982   phosphoribosylpyrophosphate synthetase          UMLS  E0571504
# 192802                                                  UMLS  E0703883
#
#            LFEUI     Type Score Count Frequency UMLS.CUI  \
# 33582   E0769306  acronym
# 70982   E0047486  acronym
# 192802  E0703882  acronym
#
#                                        TrainLF
# 33582     alpha glycerophosphate dehydrogenase
# 70982   phosphoribosylpyrophosphate synthetase
# 192802            intra-peritoneal haemorrhage

# %%
df=df.head(100)
df.shape
# Out:
# (100, 20)

# %% [markdown]
# #### Compute Similarities

# %%
df = df.sort_values(by=['NSFUI'])
df.head(10)
# Out:
#    GroupID  EntryID    SF     SFUI NormSF    NSFUI PrefSF  \
# 69          E000070   AAT  S003250    aat  N006062
# 77          E000078   AAT  S003250    aat  N006132
# 90          E000091    AB  S003282     ab  N006214
# 18          E000019    AA  S003081     aa  N006781
# 87          E000088   AAT  S003250    aat  N006795
# 19          E000020    AA  S003081     aa  N006904
# 93          E000094    AB  S003282     ab  N007093
# 1           E000002    AA  S003081     aa  N007108
# 60          E000061   AAA  S003100    aaa  N007119
# 66          E000067  AAMD  S003184   aamd  N007509
#
#                                            LF     LFUI  \
# 69                        Aachen aphasia test  L003442
# 77                     Academic Aptitude test  L003503
# 90                                Ace bandage  L003589
# 18                           African American  L004037
# 87              African animal trypanosomosis  L004047
# 19                           African-American  L004091
# 93                                Alcian blue  L004234
# 1                        Alcoholics Anonymous  L004250
# 60                Aleuria aurantia agglutinin  L004259
# 66  American Association on Mental Deficiency  L004532
#
#                            NormLF PrefLF Source     SFEUI     LFEUI     Type  \
# 69            Aachen aphasia test          UMLS  E0000051  E0500260  acronym
# 77         Academic Aptitude test          UMLS  E0000051  E0500261  acronym
# 90                    Ace bandage          UMLS  E0000052  E0338802  acronym
# 18                AfricanAmerican          UMLS  E0000048  E0420574  acronym
# 87  African animal trypanosomosis          UMLS  E0000051  E0515595  acronym
# 19                AfricanAmerican          UMLS  E0000048  E0420574  acronym
# 93                    Alcian blue          UMLS  E0000052  E0000202  acronym
# 1                                          UMLS  E0000048  E0000204  acronym
# 60    Aleuria aurantia agglutinin          UMLS  E0000049  E0598120  acronym
# 66                                         UMLS  E0000050  E0000277  acronym
#
#    Score Count Frequency UMLS.CUI                                    TrainLF
# 69                                                       Aachen aphasia test
# 77                                                    Academic Aptitude test
# 90                                                               Ace bandage
# 18                                                           AfricanAmerican
# 87                                             African animal trypanosomosis
# 19                                                           AfricanAmerican
# 93                                                               Alcian blue
# 1                                                       Alcoholics Anonymous
# 60                                               Aleuria aurantia agglutinin
# 66                                 American Association on Mental Deficiency

# %%
train = []

# %%
for NSFUI in df.NSFUI.unique():
    uniq_LFs = set(df.at[df['NSFUI'] == NSFUI]['TrainLF'].values)
    for pair in itertools.combinations(uniq_LFs, 2):
        distance = fuzz.ratio(pair[0], pair[1])
        if distance > 60:
            pair_dictionary = {'LF1':pair[0], 'LF2':pair[1], 'distance':distance} 
            train.append(pair_dictionary)

# %%
train = pd.DataFrame(train)

# %%
train.sample(3, random_state=0)

# %% [markdown]
# ## Random Subset

# %% [markdown]
# Select random subset of highly and moderately similar long forms for manual annotation.

# %%
TrainSet3 = train[train.distance < 98]
TrainSet3 = TrainSet3.sample(frac=0.10)
TrainSet3 = TrainSet3.drop(columns=['distance'])
TrainSet3['Synonym'] = ''

# %%
TrainSet1.sample(3, random_state=0)

# %% [markdown]
# #### Export

# %%
TrainSet3.to_csv('TrainingSet3.csv',
                 index=False,
                 header=True,
                 sep='|')
